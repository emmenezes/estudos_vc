# %% [markdown]
# # Aula 1 - Básico

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('imgs/watch.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# IMREAD_COLOR = 1, IMREAD_ GRAYSCALE = 0, IMREAD_UNCHANGED = -1

# %% [markdown]
# ## Como mostrar imagens com `cv2`

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Como mostrar imagens com `plt`

# %%
plt.imshow(img, cmap='gray', interpolation='bicubic')
plt.show()
